# %%
import sys
import os
from IPython.display import display
sys.path.append(os.path.abspath('C:/Users/teeyob/Car Insurance Risk & Premium Optimization/scripts'))

# %%
from Data_Loading_Preparation import clean_data
# print("Missing Values:\n", missing_values)   print("Numerical Data Summary:\n", summary_numerical)     print("Unique Values Count for Categorical Columns:\n", unique_counts)

# %%
path=('C:/Users/teeyob/Car Insurance Risk & Premium Optimization/data/MachineLearningRating_v3.txt')

# %%
cleaned_data = clean_data(path)

cleaned_data.columns
# Out:
# C:\Users\teeyob\Car Insurance Risk & Premium Optimization\scripts\Data_Loading_Preparation.py:9: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path,delimiter='|')
# Data Loaded Successfully!
# Remaining Missing Values:
#  Series([], dtype: int64)
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'AlarmImmobiliser', 'TrackingDevice',
#        'CapitalOutstanding', 'SumInsured', 'TermFrequency',
#        'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory',
# ...

# %% [markdown]
# Data Summarization

# %%
from data_summarization import data_summarization
data_summarization(cleaned_data)
# Out:
# Numerical Data Summary:
#        TotalPremium   TotalClaims    SumInsured  CalculatedPremiumPerTerm
# count  1.000098e+06  1.000098e+06  1.000098e+06              1.000098e+06
# mean   6.190550e+01  6.486119e+01  6.041727e+05              1.178757e+02
# std    2.302845e+02  2.384075e+03  1.508332e+06              3.997017e+02
# min   -7.825768e+02 -1.200241e+04  1.000000e-02              0.000000e+00
# 25%    0.000000e+00  0.000000e+00  5.000000e+03              3.224800e+00
# 50%    2.178333e+00  0.000000e+00  7.500000e+03              8.436900e+00
# 75%    2.192982e+01  0.000000e+00  2.500000e+05              9.000000e+01
# max    6.528260e+04  3.930921e+05  1.263620e+07              7.442217e+04
# Unique Values Count for Categorical Columns:
# Province           9
# PostalCode       888
# CoverCategory     28
# CoverType         22
# Gender             3
# dtype: int64

# %% [markdown]
# Data Quality Check

# %%
from data_quality_check import data_quality_check
data_quality_check(cleaned_data)
# Out:
# Remaining Missing Values:
#  Series([], dtype: int64)

# %% [markdown]
# Outlier Detection

# %%
from outlier_detection import outlier_detection
outlier_detection(cleaned_data)

# %% [markdown]
# Univariate Analysis

# %%
from univariate_analysis import univariate_analysis
univariate_analysis(cleaned_data)

# %% [markdown]
# Bivariate/Multivariate Analysis

# %%
from bivariate_analysis import bivariate_analysis
bivariate_analysis(cleaned_data)

# %% [markdown]
# Additional analysis such as exploring TotalPremium by VehicleType and SumInsured vs TotalPremium

# %%
from additional_analysis import additional_analysis
additional_analysis(cleaned_data)
